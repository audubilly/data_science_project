# %% [markdown]
# <a href="https://colab.research.google.com/github/audubilly/data_science_project/blob/main/DataScienceProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv('cereal.csv')

# %%
df.head()
# Out:
#                         name mfr type  calories  ...  shelf  weight  cups     rating
# 0                  100% Bran   N    C        70  ...      3     1.0  0.33  68.402973
# 1          100% Natural Bran   Q    C       120  ...      3     1.0  1.00  33.983679
# 2                   All-Bran   K    C        70  ...      3     1.0  0.33  59.425505
# 3  All-Bran with Extra Fiber   K    C        50  ...      3     1.0  0.50  93.704912
# 4             Almond Delight   R    C       110  ...      3     1.0  0.75  34.384843
#
# [5 rows x 16 columns]

# %%
carbohydrates = df['carbo'] + df['sugars'] + df['fiber']
df['carbohydrate'] = carbohydrates

minerals = df['potass'] + df['sodium']
df['mineral'] = minerals
df
# Out:
#                          name mfr type  ...     rating  carbohydrate  mineral
# 0                   100% Bran   N    C  ...  68.402973          21.0      410
# 1           100% Natural Bran   Q    C  ...  33.983679          18.0      150
# 2                    All-Bran   K    C  ...  59.425505          21.0      580
# 3   All-Bran with Extra Fiber   K    C  ...  93.704912          22.0      470
# 4              Almond Delight   R    C  ...  34.384843          23.0      199
# ..                        ...  ..  ...  ...        ...           ...      ...
# 72                    Triples   G    C  ...  39.106174          24.0      310
# 73                       Trix   G    C  ...  27.753301          25.0      165
# 74                 Wheat Chex   R    C  ...  49.787445          23.0      345
# 75                   Wheaties   G    C  ...  51.592193          23.0      310
# 76        Wheaties Honey Gold   G    C  ...  36.187559          25.0      260
#
# [77 rows x 18 columns]

# %%
new_df = df[['name','carbohydrate','protein','mineral','vitamins','fat']]
new_df
# Out:
#                          name  carbohydrate  protein  mineral  vitamins  fat
# 0                   100% Bran          21.0        4      410        25    1
# 1           100% Natural Bran          18.0        3      150         0    5
# 2                    All-Bran          21.0        4      580        25    1
# 3   All-Bran with Extra Fiber          22.0        4      470        25    0
# 4              Almond Delight          23.0        2      199        25    2
# ..                        ...           ...      ...      ...       ...  ...
# 72                    Triples          24.0        2      310        25    1
# 73                       Trix          25.0        1      165        25    1
# 74                 Wheat Chex          23.0        3      345        25    1
# 75                   Wheaties          23.0        3      310        25    1
# 76        Wheaties Honey Gold          25.0        2      260        25    1
#
# [77 rows x 6 columns]

# %%
carbohydrate_df = new_df[['name','carbohydrate']]
carbohydrate_df = carbohydrate_df.sort_values('carbohydrate')
carbohydrate_df
# Out:
#                          name  carbohydrate
# 57             Quaker Oatmeal           0.7
# 55               Puffed Wheat          11.0
# 54                Puffed Rice          13.0
# 1           100% Natural Bran          18.0
# 43                      Maypo          19.0
# ..                        ...           ...
# 52      Post Nat. Raisin Bran          31.0
# 49  Nutri-Grain Almond-Raisin          31.0
# 58                Raisin Bran          31.0
# 46       Mueslix Crispy Blend          33.0
# 70          Total Raisin Bran          33.0
#
# [77 rows x 2 columns]

# %%
carbohydrate_df_tail = carbohydrate_df.tail(5)
carbohydrate_df_tail
# Out:
#                          name  carbohydrate
# 52      Post Nat. Raisin Bran          31.0
# 49  Nutri-Grain Almond-Raisin          31.0
# 58                Raisin Bran          31.0
# 46       Mueslix Crispy Blend          33.0
# 70          Total Raisin Bran          33.0

# %%
plt.figure(figsize =(30,10))
plt.title('Chart of Top Cereals in Carbohydrate')
plt.xlabel('cereal_name',labelpad=15)
plt.ylabel('carbohydrate')
plt.bar(carbohydrate_df_tail['name'],carbohydrate_df_tail['carbohydrate'],color = 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
protein_df = new_df[['name','protein']]
protein_df = protein_df.sort_values('protein')
protein_df
# Out:
#                 name  protein
# 54       Puffed Rice        1
# 31    Golden Grahams        1
# 35  Honey Graham Ohs        1
# 37        Honey-comb        1
# 18     Count Chocula        1
# ..               ...      ...
# 2           All-Bran        4
# 0          100% Bran        4
# 57    Quaker Oatmeal        5
# 67         Special K        6
# 11          Cheerios        6
#
# [77 rows x 2 columns]

# %%
protein_df_tail = protein_df.tail(5)
protein_df_tail
# Out:
#               name  protein
# 2         All-Bran        4
# 0        100% Bran        4
# 57  Quaker Oatmeal        5
# 67       Special K        6
# 11        Cheerios        6

# %%
plt.figure(figsize =(30,10))
plt.title('Chart of Top Cereals in protein')
plt.xlabel('cereal_name',labelpad=15)
plt.ylabel('protein')
plt.bar(protein_df_tail['name'],protein_df_tail['protein'],color = 'green')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
mineral_df = new_df[['name','mineral']]
mineral_df = mineral_df.sort_values('mineral')
mineral_df
# Out:
#                          name  mineral
# 54                Puffed Rice       15
# 55               Puffed Wheat       50
# 20     Cream of Wheat (Quick)       79
# 30               Golden Crisp       85
# 63             Shredded Wheat       95
# ..                        ...      ...
# 28              Fruitful Bran      430
# 58                Raisin Bran      450
# 52      Post Nat. Raisin Bran      460
# 3   All-Bran with Extra Fiber      470
# 2                    All-Bran      580
#
# [77 rows x 2 columns]

# %%
mineral_df_tail = mineral_df.tail(5)
mineral_df_tail
# Out:
#                          name  mineral
# 28              Fruitful Bran      430
# 58                Raisin Bran      450
# 52      Post Nat. Raisin Bran      460
# 3   All-Bran with Extra Fiber      470
# 2                    All-Bran      580

# %%
plt.figure(figsize =(30,10))
plt.title('Chart of Top Cereals in mineral')
plt.xlabel('cereal_name',labelpad=15)
plt.ylabel('mineral')
plt.bar(mineral_df_tail['name'],mineral_df_tail['mineral'],color = 'yellow')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
vitamins_df = new_df[['name','vitamins']]
vitamins_df = vitamins_df.sort_values('vitamins')
vitamins_df
# Out:
#                            name  vitamins
# 63               Shredded Wheat         0
# 55                 Puffed Wheat         0
# 57               Quaker Oatmeal         0
# 54                  Puffed Rice         0
# 64       Shredded Wheat 'n'Bran         0
# ..                          ...       ...
# 53                   Product 19       100
# 70            Total Raisin Bran       100
# 69            Total Corn Flakes       100
# 71            Total Whole Grain       100
# 38  Just Right Crunchy  Nuggets       100
#
# [77 rows x 2 columns]

# %%
vitamins_df_tail = vitamins_df.tail(5)
vitamins_df_tail
# Out:
#                            name  vitamins
# 53                   Product 19       100
# 70            Total Raisin Bran       100
# 69            Total Corn Flakes       100
# 71            Total Whole Grain       100
# 38  Just Right Crunchy  Nuggets       100

# %%
plt.figure(figsize =(30,10))
plt.title('Chart of Top Cereals in vitamins')
plt.xlabel('cereal_name',labelpad=15)
plt.ylabel('vitamins')
plt.bar(vitamins_df_tail['name'],vitamins_df_tail['vitamins'],color = 'orange')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fat_df = new_df[['name','fat']]
fat_df = fat_df.sort_values('fat')
fat_df
# Out:
#                                  name  fat
# 20             Cream of Wheat (Quick)    0
# 55                       Puffed Wheat    0
# 26                Frosted Mini-Wheats    0
# 25                     Frosted Flakes    0
# 60                     Raisin Squares    0
# ..                                ...  ...
# 12              Cinnamon Toast Crunch    3
# 45  Muesli Raisins; Peaches; & Pecans    3
# 44   Muesli Raisins; Dates; & Almonds    3
# 19                 Cracklin' Oat Bran    3
# 1                   100% Natural Bran    5
#
# [77 rows x 2 columns]

# %%
fat_df_tail = fat_df.tail(5)
fat_df_tail
# Out:
#                                  name  fat
# 12              Cinnamon Toast Crunch    3
# 45  Muesli Raisins; Peaches; & Pecans    3
# 44   Muesli Raisins; Dates; & Almonds    3
# 19                 Cracklin' Oat Bran    3
# 1                   100% Natural Bran    5

# %%
plt.figure(figsize =(30,10))
plt.title('Chart of Top Cereals in fat')
plt.xlabel('cereal_name',labelpad=15)
plt.ylabel('fat')
plt.bar(fat_df_tail['name'],fat_df_tail['fat'],color = 'purple')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #Food for Diabetes

# %%
df
fiber_df = df[['name','fiber']]
fiber_df
# Out:
#                          name  fiber
# 0                   100% Bran   10.0
# 1           100% Natural Bran    2.0
# 2                    All-Bran    9.0
# 3   All-Bran with Extra Fiber   14.0
# 4              Almond Delight    1.0
# ..                        ...    ...
# 72                    Triples    0.0
# 73                       Trix    0.0
# 74                 Wheat Chex    3.0
# 75                   Wheaties    3.0
# 76        Wheaties Honey Gold    1.0
#
# [77 rows x 2 columns]

# %%
sorted_fiber_df = fiber_df.sort_values('fiber')
sorted_fiber_df
# Out:
#                          name  fiber
# 12      Cinnamon Toast Crunch    0.0
# 31             Golden Grahams    0.0
# 37                 Honey-comb    0.0
# 40                        Kix    0.0
# 18              Count Chocula    0.0
# ..                        ...    ...
# 58                Raisin Bran    5.0
# 52      Post Nat. Raisin Bran    6.0
# 2                    All-Bran    9.0
# 0                   100% Bran   10.0
# 3   All-Bran with Extra Fiber   14.0
#
# [77 rows x 2 columns]

# %%
sorted_fiber_df = sorted_fiber_df.tail()
sorted_fiber_df
# Out:
#                          name  fiber
# 58                Raisin Bran    5.0
# 52      Post Nat. Raisin Bran    6.0
# 2                    All-Bran    9.0
# 0                   100% Bran   10.0
# 3   All-Bran with Extra Fiber   14.0

# %%
plt.figure(figsize =(10,5))
plt.title('Chart of Top 5 Cereals with high content of fiber')
plt.xlabel('cereal_name',labelpad=15)
plt.ylabel('fiber content')
plt.bar(sorted_fiber_df['name'],sorted_fiber_df['fiber'],color = 'gold')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #All-Bran with Extra Fiber is the best cereal for diabetic patients.

# %%
potas_sorted_df = df.sort_values('potass')
potas_sorted_df
# Out:
#                          name mfr type  ...     rating  carbohydrate  mineral
# 20     Cream of Wheat (Quick)   N    H  ...  64.533816          22.0       79
# 4              Almond Delight   R    C  ...  34.384843          23.0      199
# 54                Puffed Rice   Q    C  ...  60.756112          13.0       15
# 17                  Corn Pops   K    C  ...  35.782791          26.0      110
# 15                  Corn Chex   R    C  ...  41.445019          25.0      305
# ..                        ...  ..  ...  ...        ...           ...      ...
# 58                Raisin Bran   K    C  ...  39.259197          31.0      450
# 52      Post Nat. Raisin Bran   P    C  ...  37.840594          31.0      460
# 0                   100% Bran   N    C  ...  68.402973          21.0      410
# 2                    All-Bran   K    C  ...  59.425505          21.0      580
# 3   All-Bran with Extra Fiber   K    C  ...  93.704912          22.0      470
#
# [77 rows x 18 columns]

# %%
potas_sorted_df = potas_sorted_df.tail(20)
potas_sorted_df
# Out:
#                                       name mfr  ... carbohydrate  mineral
# 22                  Crispy Wheat & Raisins   G  ...         23.0      260
# 65               Shredded Wheat spoon size   N  ...         23.0      120
# 8                                Bran Chex   R  ...         25.0      325
# 49               Nutri-Grain Almond-Raisin   K  ...         31.0      350
# 1                        100% Natural Bran   Q  ...         18.0      150
# 59                         Raisin Nut Bran   G  ...         21.0      280
# 64                  Shredded Wheat 'n'Bran   N  ...         23.0      140
# 19                      Cracklin' Oat Bran   K  ...         21.0      300
# 46                    Mueslix Crispy Blend   K  ...         33.0      310
# 44        Muesli Raisins; Dates; & Almonds   R  ...         30.0      265
# 45       Muesli Raisins; Peaches; & Pecans   R  ...         30.0      320
# 28                           Fruitful Bran   K  ...         31.0      430
# 9                              Bran Flakes   P  ...         23.0      400
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P  ...         27.0      360
# 70                       Total Raisin Bran   G  ...         33.0      420
# 58                             Raisin Bran   K  ...         31.0      450
# 52                   Post Nat. Raisin Bran   P  ...         31.0      460
# 0                                100% Bran   N  ...         21.0      410
# 2                                 All-Bran   K  ...         21.0      580
# 3                All-Bran with Extra Fiber   K  ...         22.0      470
#
# [20 rows x 18 columns]

# %%
p_sodium_sorted = potas_sorted_df.sort_values('sodium')
p_sodium_sorted
# Out:
#                                       name mfr  ... carbohydrate  mineral
# 65               Shredded Wheat spoon size   N  ...         23.0      120
# 64                  Shredded Wheat 'n'Bran   N  ...         23.0      140
# 1                        100% Natural Bran   Q  ...         18.0      150
# 44        Muesli Raisins; Dates; & Almonds   R  ...         30.0      265
# 0                                100% Bran   N  ...         21.0      410
# 19                      Cracklin' Oat Bran   K  ...         21.0      300
# 22                  Crispy Wheat & Raisins   G  ...         23.0      260
# 59                         Raisin Nut Bran   G  ...         21.0      280
# 3                All-Bran with Extra Fiber   K  ...         22.0      470
# 46                    Mueslix Crispy Blend   K  ...         33.0      310
# 45       Muesli Raisins; Peaches; & Pecans   R  ...         30.0      320
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P  ...         27.0      360
# 70                       Total Raisin Bran   G  ...         33.0      420
# 52                   Post Nat. Raisin Bran   P  ...         31.0      460
# 8                                Bran Chex   R  ...         25.0      325
# 9                              Bran Flakes   P  ...         23.0      400
# 58                             Raisin Bran   K  ...         31.0      450
# 49               Nutri-Grain Almond-Raisin   K  ...         31.0      350
# 28                           Fruitful Bran   K  ...         31.0      430
# 2                                 All-Bran   K  ...         21.0      580
#
# [20 rows x 18 columns]

# %%
p_sodium_sorted.head(10)
# Out:
#                                 name mfr type  ...     rating  carbohydrate  mineral
# 65         Shredded Wheat spoon size   N    C  ...  72.801787          23.0      120
# 64            Shredded Wheat 'n'Bran   N    C  ...  74.472949          23.0      140
# 1                  100% Natural Bran   Q    C  ...  33.983679          18.0      150
# 44  Muesli Raisins; Dates; & Almonds   R    C  ...  37.136863          30.0      265
# 0                          100% Bran   N    C  ...  68.402973          21.0      410
# 19                Cracklin' Oat Bran   K    C  ...  40.448772          21.0      300
# 22            Crispy Wheat & Raisins   G    C  ...  36.176196          23.0      260
# 59                   Raisin Nut Bran   G    C  ...  39.703400          21.0      280
# 3          All-Bran with Extra Fiber   K    C  ...  93.704912          22.0      470
# 46              Mueslix Crispy Blend   K    C  ...  30.313351          33.0      310
#
# [10 rows x 18 columns]

# %%
hbp_df = p_sodium_sorted[['name','potass','sodium','fat']]
hbp_df
# Out:
#                                       name  potass  sodium  fat
# 65               Shredded Wheat spoon size     120       0    0
# 64                  Shredded Wheat 'n'Bran     140       0    0
# 1                        100% Natural Bran     135      15    5
# 44        Muesli Raisins; Dates; & Almonds     170      95    3
# 0                                100% Bran     280     130    1
# 19                      Cracklin' Oat Bran     160     140    3
# 22                  Crispy Wheat & Raisins     120     140    1
# 59                         Raisin Nut Bran     140     140    2
# 3                All-Bran with Extra Fiber     330     140    0
# 46                    Mueslix Crispy Blend     160     150    2
# 45       Muesli Raisins; Peaches; & Pecans     170     150    3
# 27  Fruit & Fibre Dates; Walnuts; and Oats     200     160    2
# 70                       Total Raisin Bran     230     190    1
# 52                   Post Nat. Raisin Bran     260     200    1
# 8                                Bran Chex     125     200    1
# 9                              Bran Flakes     190     210    0
# 58                             Raisin Bran     240     210    1
# 49               Nutri-Grain Almond-Raisin     130     220    2
# 28                           Fruitful Bran     190     240    0
# 2                                 All-Bran     320     260    1

# %%
hbp_rec_df = hbp_df.head()

# %%
hbp_rec_df = hbp_rec_df.reset_index()
hbp_rec_df
# Out:
#    index                              name  potass  sodium  fat
# 0     65         Shredded Wheat spoon size     120       0    0
# 1     64            Shredded Wheat 'n'Bran     140       0    0
# 2      1                 100% Natural Bran     135      15    5
# 3     44  Muesli Raisins; Dates; & Almonds     170      95    3
# 4      0                         100% Bran     280     130    1

# %%
hbp_rec_df.set_index('name',inplace=True)
hbp_rec_df.plot(kind = 'bar', stacked ='True', title = "chart of cereals eligible for people with high blood pressure")
